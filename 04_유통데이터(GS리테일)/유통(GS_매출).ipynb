# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as fm
# %matplotlib inline

# %%
path = "C:/Windows/Fonts/Hancom Gothic Regular.ttf"
font_name = fm.FontProperties(fname=path,size=18).get_name()
print(font_name)
plt.rc('font',family=font_name)
# Out:
# Hancom Gothic

# %%
data = pd.read_csv("C:/Users/Dong/con_data/2020빅콘테스트 문제데이터(혁신아이디어분야)/04_유통데이터(GS리테일)/매출.csv",
                 encoding='KSC5601', sep=",")

# %%
data.head()
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        PVN        BOR       ADMD   20190201   20190202   20190203
# 2         전체        NaN        NaN     119.8%     101.8%      96.4%
# 3      서울특별시        NaN        NaN     118.9%     100.4%      95.4%
# 4      서울특별시         중구        NaN     138.0%     103.8%     101.3%
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 234 Unnamed: 235  \
# 0        NaN        NaN        NaN        NaN  ...          NaN          NaN
# 1   20190204   20190205   20190206   20190207  ...     20200522     20200523
# 2      91.9%     102.8%      90.0%     106.2%  ...       108.1%       102.0%
# 3      90.0%     103.6%      89.3%     108.0%  ...       116.3%       107.9%
# 4      89.9%     100.3%      89.3%     126.5%  ...       123.0%        99.8%
#
#   Unnamed: 236 Unnamed: 237 Unnamed: 238 Unnamed: 239 Unnamed: 240  \
# ...

# %%
data.drop(0,inplace=True)

# %%
data
# Out:
#     Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 1          PVN        BOR       ADMD   20190201   20190202   20190203
# 2           전체        NaN        NaN     119.8%     101.8%      96.4%
# 3        서울특별시        NaN        NaN     118.9%     100.4%      95.4%
# 4        서울특별시         중구        NaN     138.0%     103.8%     101.3%
# 5        서울특별시         중구        소공동     166.8%     111.5%     121.2%
# ..         ...        ...        ...        ...        ...        ...
# 320        NaN        NaN        NaN        NaN        NaN        NaN
# 321        NaN        NaN        NaN        NaN        NaN        NaN
# 322        NaN        NaN        NaN        NaN        NaN        NaN
# 323        NaN        NaN        NaN        NaN        NaN        NaN
# 324        NaN        NaN        NaN        NaN        NaN        NaN
#
#     Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 234  \
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0      256
# Unnamed: 1      259
# Unnamed: 2      263
# Unnamed: 3      256
# Unnamed: 4      256
#                ...
# Unnamed: 239    256
# Unnamed: 240    256
# Unnamed: 241    256
# Unnamed: 242    256
# Unnamed: 243    256
# Length: 244, dtype: int64

# %%
dataT = data.T
dataT.head()
# Out:
#                  1       2       3       4       5       6       7       8    \
# Unnamed: 0       PVN      전체   서울특별시   서울특별시   서울특별시   서울특별시   서울특별시   서울특별시
# Unnamed: 1       BOR     NaN     NaN      중구      중구      중구      중구      중구
# Unnamed: 2      ADMD     NaN     NaN     NaN     소공동     회현동      명동      필동
# Unnamed: 3  20190201  119.8%  118.9%  138.0%  166.8%  121.7%  174.5%  131.9%
# Unnamed: 4  20190202  101.8%  100.4%  103.8%  111.5%  123.2%   87.8%   84.7%
#
#               9       10   ...  315  316  317  318  319  320  321  322  323  \
# Unnamed: 0  서울특별시   서울특별시  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Unnamed: 1     중구      중구  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Unnamed: 2    장충동     광희동  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Unnamed: 3  68.4%  133.4%  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# Unnamed: 4  63.5%  121.9%  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#             324
# Unnamed: 0  NaN
# ...

# %%
dataT_1 = dataT[:3]

# %%
t_data = data.T

# %%
dataT_1.index = ["시코드", "구코드", "행정동코드"]

# %%
dataT_2 = dataT[3:]

# %%
dataT_2
# Out:
#                1      2      3      4      5      6      7      8     9    \
# 20190201  20190201  119.8  118.9  138.0  166.8  121.7  174.5  131.9  68.4
# 20190202  20190202  101.8  100.4  103.8  111.5  123.2   87.8   84.7  63.5
# 20190203  20190203   96.4   95.4  101.3  121.2  121.7  104.2   80.5  62.8
# 20190204  20190204   91.9   90.0   89.9  103.4  126.4   90.1   71.3  54.9
# 20190205  20190205  102.8  103.6  100.3  111.3  124.5  103.4   80.3  57.5
# ...            ...    ...    ...    ...    ...    ...    ...    ...   ...
# 20200527  20200527  106.3  114.8  124.3  150.0  123.7  131.8  121.4  72.0
# 20200528  20200528  107.6  117.0  128.9  156.7  118.0  138.5  131.3  76.6
# 20200529  20200529  113.8  122.6  129.6  149.2  123.2  138.3  128.5  77.8
# 20200530  20200530  104.6  111.0  100.3   78.5   79.4   72.2   83.0  73.5
# 20200531  20200531   92.9   97.8   85.0   68.0   77.4   51.4   71.4  64.5
#
#             10   ...  315  316  317  318  319  320  321  322  323  324
# ...

# %%
number = dataT_2[1]

# %%
dataT_2.index = list(number)
dataT_2.head()
# Out:
#                1       2       3       4       5       6       7       8    \
# 20190201  20190201  119.8%  118.9%  138.0%  166.8%  121.7%  174.5%  131.9%
# 20190202  20190202  101.8%  100.4%  103.8%  111.5%  123.2%   87.8%   84.7%
# 20190203  20190203   96.4%   95.4%  101.3%  121.2%  121.7%  104.2%   80.5%
# 20190204  20190204   91.9%   90.0%   89.9%  103.4%  126.4%   90.1%   71.3%
# 20190205  20190205  102.8%  103.6%  100.3%  111.3%  124.5%  103.4%   80.3%
#
#             9       10   ...  315  316  317  318  319  320  321  322  323  324
# 20190201  68.4%  133.4%  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 20190202  63.5%  121.9%  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 20190203  62.8%  121.5%  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 20190204  54.9%  108.3%  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 20190205  57.5%   99.3%  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 324 columns]

# %%
dataT_2 = dataT_2.apply(lambda x: x.str.replace("%",""), axis = 1)

# %%
dataT_2 = dataT_2.apply(pd.to_numeric)

# %%
newdata = pd.concat([dataT_1,dataT_2])

# %%
del newdata[1]

# %%
newdata.head()
# Out:
#             2      3      4      5      6      7      8      9      10   \
# 시코드          전체  서울특별시  서울특별시  서울특별시  서울특별시  서울특별시  서울특별시  서울특별시  서울특별시
# 구코드         NaN    NaN     중구     중구     중구     중구     중구     중구     중구
# 행정동코드       NaN    NaN    NaN    소공동    회현동     명동     필동    장충동    광희동
# 20190201  119.8  118.9    138  166.8  121.7  174.5  131.9   68.4  133.4
# 20190202  101.8  100.4  103.8  111.5  123.2   87.8   84.7   63.5  121.9
#
#             11   ...  315  316  317  318  319  320  321  322  323  324
# 시코드       서울특별시  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 구코드          중구  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 행정동코드      을지로동  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 20190201  194.1  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 20190202  165.3  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 323 columns]

# %%
newdata.fillna(" ",inplace=True)

# %%
newdata = newdata.iloc[:244,:67]

# %%
newdataT = newdata.T
newdataT.head()
# Out:
#      시코드 구코드 행정동코드 20190201 20190202 20190203 20190204 20190205 20190206  \
# 2     전체              119.8    101.8     96.4     91.9    102.8       90
# 3  서울특별시              118.9    100.4     95.4       90    103.6     89.3
# 4  서울특별시  중구            138    103.8    101.3     89.9    100.3     89.3
# 5  서울특별시  중구   소공동    166.8    111.5    121.2    103.4    111.3    105.5
# 6  서울특별시  중구   회현동    121.7    123.2    121.7    126.4    124.5    118.7
#
#   20190207  ... 20200522 20200523 20200524 20200525 20200526 20200527  \
# 2    106.2  ...    108.1      102     88.6    102.1    106.8    106.3
# 3      108  ...    116.3    107.9       93    109.9    114.3    114.8
# 4    126.5  ...      123     99.8     77.8    118.7      126    124.3
# 5    183.4  ...    148.4       82     60.9    133.5    147.5      150
# 6    118.5  ...    112.3     81.3     66.6    119.9    125.4    123.7
#
#   20200528 20200529 20200530 20200531
# 2    107.6    113.8    104.6     92.9
# ...

# %%
n_data = newdataT.loc[[4,20,40,48],list(newdataT.columns)]
n_data.head()
# Out:
#       시코드  구코드 행정동코드 20190201 20190202 20190203 20190204 20190205 20190206  \
# 4   서울특별시   중구            138    103.8    101.3     89.9    100.3     89.3
# 20  서울특별시  노원구          101.4     97.8     90.8       90    106.2     89.3
# 40  대구광역시   중구          200.5    134.7      123    107.8    113.4      117
# 48  대구광역시  수성구             92     93.8     89.5     91.8     96.2       82
#
#    20190207  ... 20200522 20200523 20200524 20200525 20200526 20200527  \
# 4     126.5  ...      123     99.8     77.8    118.7      126    124.3
# 20     91.2  ...      110    114.7    105.7    101.5    103.4    105.8
# 40      134  ...    100.2     94.9     83.3     91.8     99.2     94.6
# 48     89.9  ...     86.3     87.5     77.8     82.3     86.8     84.6
#
#    20200528 20200529 20200530 20200531
# 4     128.9    129.6    100.3       85
# 20    105.7    116.1    120.4    108.6
# 40     95.2     96.1     91.8     83.8
# 48     83.9     93.3     90.6     81.9
#
# [4 rows x 244 columns]

# %%
del n_data["행정동코드"]

# %%
n_data.T.head()
# Out:
#              4      20     40     48
# 시코드       서울특별시  서울특별시  대구광역시  대구광역시
# 구코드          중구    노원구     중구    수성구
# 20190201    138  101.4  200.5     92
# 20190202  103.8   97.8  134.7   93.8
# 20190203  101.3   90.8    123   89.5

# %%
data_2019_02 = n_data.T[3:31].mean()
data_2019_03 = n_data.T[31:62].mean()
data_2019_04 = n_data.T[62:92].mean()
data_2019_05 = n_data.T[92:123].mean()
data_2020_02 = n_data.T[123:152].mean()
data_2020_03 = n_data.T[152:183].mean()
data_2020_04 = n_data.T[183:213].mean()
data_2020_05 = n_data.T[213:244].mean()

# %%
gu_data =pd.concat([data_2019_02, data_2019_03, data_2019_04, data_2019_05, data_2020_02, data_2020_03, data_2020_04, data_2020_05],axis=1)

# %%
gu_data.columns = ["201902", "201903", "201904", "201905", "202002", "202003", "202004", "202005"]

# %%
gu_data.index = ["서울 중구", "서울 노원구", "대구 중구", "대구 수성구"]

# %%
gu_data.head()
# Out:
#             201902      201903      201904      201905      202002  \
# 서울 중구   133.842857  149.883871  154.970000  155.900000  130.368966
# 서울 노원구   99.064286  103.280645  106.093333  110.070968   99.668966
# 대구 중구   136.928571  130.587097  113.050000  117.200000   98.341379
# 대구 수성구   90.060714   86.122581   90.546667   92.187097   82.617241
#
#             202003     202004      202005
# 서울 중구   101.261290  99.643333  107.566667
# 서울 노원구   93.541935  97.033333  104.910000
# 대구 중구    69.729032  78.330000   90.560000
# 대구 수성구   70.148387  73.616667   82.306667

# %%
gu_dataT = gu_data.T
gu_dataT
# Out:
#              서울 중구      서울 노원구       대구 중구     대구 수성구
# 201902  133.842857   99.064286  136.928571  90.060714
# 201903  149.883871  103.280645  130.587097  86.122581
# 201904  154.970000  106.093333  113.050000  90.546667
# 201905  155.900000  110.070968  117.200000  92.187097
# 202002  130.368966   99.668966   98.341379  82.617241
# 202003  101.261290   93.541935   69.729032  70.148387
# 202004   99.643333   97.033333   78.330000  73.616667
# 202005  107.566667  104.910000   90.560000  82.306667

# %%
data_2019=gu_dataT[:4]

# %%
data_2020=gu_dataT[4:]

# %%
X = np.arange(4)
fig = plt.figure(figsize = (30,35))
fig.suptitle("매출지수",fontsize= 24)
for i in range(0,4):
    plt.subplot(4,4,i+1)
    plt.bar(X+2.00, list(data_2019[data_2019.columns[i]]), label='2019년',color = 'b', width = 0.25)
    plt.bar(X+2.25, list(data_2020[data_2020.columns[i]]), label='2020년',color = 'r', width = 0.25)
    plt.legend(loc="best",frameon=False)
    plt.title(gu_dataT.columns[i])
    plt.ylim(0,160)
    plt.xlabel("월")
    plt.ylabel("%(퍼센트)")
plt.show()
