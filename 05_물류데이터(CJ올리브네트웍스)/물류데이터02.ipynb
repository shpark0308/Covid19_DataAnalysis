# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import matplotlib.pyplot as plt
plt.rc('font',family='Malgun Gothic')
plt.rc('axes',unicode_minus=False)

# %%
df = pd.read_excel("2020 빅콘테스트_CJ올리브네트웍스_제공DB.xlsx",sheet_name="Sheet1")
df.head()
# Out:
#    DL_YMD DL_GD_LCLS_NM  DL_GD_LCLS_CD CTPV_NM  CTPV_CD CTGG_NM  CTGG_CD  \
# 0  190201         도서/음반             12   서울특별시       11      중구       14
# 1  190201       가구/인테리어             10   서울특별시       11      중구       14
# 2  190201       가구/인테리어             10   대구광역시       27      중구       11
# 3  190201         도서/음반             12   대구광역시       27      중구       11
# 4  190201        디지털/가전             13   대구광역시       27     수성구       26
#
#   HDNG_NM  HDNG_CD  INVC_CONT
# 0     동화동      665         16
# 1     신당동      615          4
# 2    성내1동      565          1
# 3    남산2동      650          6
# 4    고산3동      690         21

# %%
df.shape
# Out:
# (156571, 10)

# %%
df['DL_GD_LCLS_NM'].value_counts()
# Out:
# 식품         16478
# 생활건강       16474
# 화장품/미용     16425
# 패션의류       16399
# 도서/음반      16364
# 디지털/가전     16259
# 패션잡화       16220
# 가구/인테리어    15666
# 스포츠/레저     13966
# 출산/육아      12320
# Name: DL_GD_LCLS_NM, dtype: int64

# %%
df_dlymd_01 = df[df['DL_YMD'].astype(str).str.startswith('1902')]
df_dlymd_01.describe(include='all')
# Out:
#               DL_YMD DL_GD_LCLS_NM  DL_GD_LCLS_CD CTPV_NM       CTPV_CD  \
# count    16607.00000         16607   16607.000000   16607  16607.000000
# unique           NaN            10            NaN       2           NaN
# top              NaN          생활건강            NaN   대구광역시           NaN
# freq             NaN          1798            NaN    8326           NaN
# mean    190215.86590           NaN      16.113928     NaN     19.021678
# std          7.55929           NaN       3.439017     NaN      8.000212
# min     190201.00000           NaN      10.000000     NaN     11.000000
# 25%     190210.00000           NaN      13.000000     NaN     11.000000
# 50%     190216.00000           NaN      17.000000     NaN     27.000000
# 75%     190222.00000           NaN      19.000000     NaN     27.000000
# max     190228.00000           NaN      21.000000     NaN     27.000000
#
#        CTGG_NM       CTGG_CD HDNG_NM       HDNG_CD     INVC_CONT
# ...

# %%
# object -> max 값이면 아스키코드로 반환함
# df_dlymd.max()
df_dlymd_02 = df[df['DL_YMD'].astype(str).str.startswith('1903')]
df_dlymd_02.describe(include='all')
# Out:
#                DL_YMD DL_GD_LCLS_NM  DL_GD_LCLS_CD CTPV_NM       CTPV_CD  \
# count    20158.000000         20158   20158.000000   20158  20158.000000
# unique            NaN            10            NaN       2           NaN
# top               NaN            식품            NaN   대구광역시           NaN
# freq              NaN          2138            NaN   10126           NaN
# mean    190316.048120           NaN      16.080167     NaN     19.037305
# std          8.828759           NaN       3.462572     NaN      8.000111
# min     190301.000000           NaN      10.000000     NaN     11.000000
# 25%     190308.000000           NaN      13.000000     NaN     11.000000
# 50%     190316.000000           NaN      16.000000     NaN     27.000000
# 75%     190324.000000           NaN      19.000000     NaN     27.000000
# max     190331.000000           NaN      21.000000     NaN     27.000000
#
#        CTGG_NM       CTGG_CD HDNG_NM       HDNG_CD     INVC_CONT
# ...

# %%
df_dlymd_03 = df[df['DL_YMD'].astype(str).str.startswith('1904')]
df_dlymd_03.describe(include='all')
# Out:
#                DL_YMD DL_GD_LCLS_NM  DL_GD_LCLS_CD CTPV_NM       CTPV_CD  \
# count    19802.000000         19802   19802.000000   19802  19802.000000
# unique            NaN            10            NaN       2           NaN
# top               NaN        화장품/미용            NaN   대구광역시           NaN
# freq              NaN          2070            NaN    9972           NaN
# mean    190415.447985           NaN      16.074083     NaN     19.057368
# std          8.681274           NaN       3.463098     NaN      7.999996
# min     190401.000000           NaN      10.000000     NaN     11.000000
# 25%     190408.000000           NaN      13.000000     NaN     11.000000
# 50%     190416.000000           NaN      16.000000     NaN     27.000000
# 75%     190423.000000           NaN      19.000000     NaN     27.000000
# max     190430.000000           NaN      21.000000     NaN     27.000000
#
#        CTGG_NM       CTGG_CD HDNG_NM       HDNG_CD     INVC_CONT
# ...

# %%
df_dlymd_04 = df[df['DL_YMD'].astype(str).str.startswith('1905')]
df_dlymd_04.describe(include='all')
# Out:
#                DL_YMD DL_GD_LCLS_NM  DL_GD_LCLS_CD CTPV_NM       CTPV_CD  \
# count    20325.000000         20325   20325.000000   20325  20325.000000
# unique            NaN            10            NaN       2           NaN
# top               NaN            식품            NaN   대구광역시           NaN
# freq              NaN          2139            NaN   10238           NaN
# mean    190516.147454           NaN      16.077245     NaN     19.059434
# std          8.951836           NaN       3.455788     NaN      7.999976
# min     190501.000000           NaN      10.000000     NaN     11.000000
# 25%     190508.000000           NaN      13.000000     NaN     11.000000
# 50%     190516.000000           NaN      16.000000     NaN     27.000000
# 75%     190524.000000           NaN      19.000000     NaN     27.000000
# max     190531.000000           NaN      21.000000     NaN     27.000000
#
#        CTGG_NM       CTGG_CD HDNG_NM       HDNG_CD     INVC_CONT
# ...

# %%
df_dlymd_05 = df[df['DL_YMD'].astype(str).str.startswith('2002')]
df_dlymd_05.describe(include='all')
# Out:
#                DL_YMD DL_GD_LCLS_NM  DL_GD_LCLS_CD CTPV_NM       CTPV_CD  \
# count    19070.000000         19070   19070.000000   19070  19070.000000
# unique            NaN            10            NaN       2           NaN
# top               NaN        화장품/미용            NaN   대구광역시           NaN
# freq              NaN          2001            NaN    9625           NaN
# mean    200215.078867           NaN      16.080860     NaN     19.075511
# std          8.338226           NaN       3.457475     NaN      7.999853
# min     200201.000000           NaN      10.000000     NaN     11.000000
# 25%     200208.000000           NaN      13.000000     NaN     11.000000
# 50%     200215.000000           NaN      16.000000     NaN     27.000000
# 75%     200222.000000           NaN      19.000000     NaN     27.000000
# max     200229.000000           NaN      21.000000     NaN     27.000000
#
#        CTGG_NM       CTGG_CD HDNG_NM       HDNG_CD     INVC_CONT
# ...

# %%
df_dlymd_06 = df[df['DL_YMD'].astype(str).str.startswith('2003')]
df_dlymd_06.describe(include='all')
# Out:
#                DL_YMD DL_GD_LCLS_NM  DL_GD_LCLS_CD CTPV_NM       CTPV_CD  \
# count    20512.000000         20512   20512.000000   20512  20512.000000
# unique            NaN            10            NaN       2           NaN
# top               NaN        화장품/미용            NaN   대구광역시           NaN
# freq              NaN          2139            NaN   10360           NaN
# mean    200316.005168           NaN      16.071275     NaN     19.081123
# std          8.938867           NaN       3.456830     NaN      7.999784
# min     200301.000000           NaN      10.000000     NaN     11.000000
# 25%     200308.000000           NaN      13.000000     NaN     11.000000
# 50%     200316.000000           NaN      16.000000     NaN     27.000000
# 75%     200324.000000           NaN      19.000000     NaN     27.000000
# max     200331.000000           NaN      21.000000     NaN     27.000000
#
#        CTGG_NM       CTGG_CD HDNG_NM       HDNG_CD     INVC_CONT
# ...

# %%
df_dlymd_07 = df[df['DL_YMD'].astype(str).str.startswith('2004')] # 근데 생각보다 사가는게 식품은 아니였던것같음
df_dlymd_07.describe(include='all')
# Out:
#                DL_YMD DL_GD_LCLS_NM  DL_GD_LCLS_CD CTPV_NM       CTPV_CD  \
# count    19621.000000         19621   19621.000000   19621  19621.000000
# unique            NaN            10            NaN       2           NaN
# top               NaN         도서/음반            NaN   대구광역시           NaN
# freq              NaN          2070            NaN    9890           NaN
# mean    200415.381326           NaN      16.091687     NaN     19.064829
# std          8.626610           NaN       3.453891     NaN      7.999941
# min     200401.000000           NaN      10.000000     NaN     11.000000
# 25%     200408.000000           NaN      13.000000     NaN     11.000000
# 50%     200416.000000           NaN      16.000000     NaN     27.000000
# 75%     200423.000000           NaN      19.000000     NaN     27.000000
# max     200430.000000           NaN      21.000000     NaN     27.000000
#
#        CTGG_NM       CTGG_CD HDNG_NM       HDNG_CD     INVC_CONT
# ...

# %%
df_dlymd_08 = df[df['DL_YMD'].astype(str).str.startswith('2005')]
df_dlymd_08.describe(include='all')
# Out:
#                DL_YMD DL_GD_LCLS_NM  DL_GD_LCLS_CD CTPV_NM       CTPV_CD  \
# count    20476.000000         20476   20476.000000   20476  20476.000000
# unique            NaN            10            NaN       2           NaN
# top               NaN            식품            NaN   대구광역시           NaN
# freq              NaN          2139            NaN   10336           NaN
# mean    200515.956046           NaN      16.061975     NaN     19.076577
# std          8.886242           NaN       3.463991     NaN      7.999829
# min     200501.000000           NaN      10.000000     NaN     11.000000
# 25%     200508.000000           NaN      13.000000     NaN     11.000000
# 50%     200516.000000           NaN      16.000000     NaN     27.000000
# 75%     200524.000000           NaN      19.000000     NaN     27.000000
# max     200531.000000           NaN      21.000000     NaN     27.000000
#
#        CTGG_NM       CTGG_CD HDNG_NM       HDNG_CD     INVC_CONT
# ...

# %%
# 그럼 온라인으로 사가는건지 아님 직접 매장 방문인지는 유동인구와 결합해서 알아보면 될것같음
df.groupby(df.DL_YMD.astype(str).str[0:4])[['DL_GD_LCLS_NM','CTPV_NM','CTGG_NM']].describe(include='all')
# 오히려 화장품/미용쪽에서만 더 부각을 드러내는 것같음
# 그럼 구매는 어느정도 하는지 분석해보기
# Out:
#        DL_GD_LCLS_NM                      CTPV_NM                       \
#                count unique     top  freq   count unique    top   freq
# DL_YMD
# 1902           16607     10    생활건강  1798   16607      2  대구광역시   8326
# 1903           20158     10      식품  2138   20158      2  대구광역시  10126
# 1904           19802     10  화장품/미용  2070   19802      2  대구광역시   9972
# 1905           20325     10      식품  2139   20325      2  대구광역시  10238
# 2002           19070     10  화장품/미용  2001   19070      2  대구광역시   9625
# 2003           20512     10  화장품/미용  2139   20512      2  대구광역시  10360
# 2004           19621     10   도서/음반  2070   19621      2  대구광역시   9890
# 2005           20476     10      식품  2139   20476      2  대구광역시  10336
#
#        CTGG_NM
#          count unique top  freq
# DL_YMD
# 1902     16607      3  중구  6332
# 1903     20158      3  중구  7754
# 1904     19802      3  중구  7651
# 1905     20325      3  중구  7835
# 2002     19070      3  중구  7338
# ...

# %%
df.groupby(df.DL_YMD.astype(str).str[0:4])['INVC_CONT'].sum().plot() 
# 코로나 이후로 확실히 뛰기는 했다

# %%
# 일단 지역적인것까지 분류하고 다음걸로 넘어가기
df_local = df.groupby(['CTPV_NM','CTGG_NM']).sum()
df_local
# Out:
#                       DL_YMD  DL_GD_LCLS_CD  CTPV_CD  CTGG_CD   HDNG_CD  \
# CTPV_NM CTGG_NM
# 대구광역시   수성구      10266847182         844449  1418175  1365650  31706296
#         중구        5150343084         423953   711396   289828  16164699
# 서울특별시   노원구       8561607987         704552   481855  1533175  27771420
#         중구        6624453293         544799   372823   474502  20659495
#
#                  INVC_CONT
# CTPV_NM CTGG_NM
# 대구광역시   수성구        5800813
#         중구         1592693
# 서울특별시   노원구        6811952
#         중구         3620016

# %%
df_local['INVC_CONT'].plot()
# 지역적으로 봤을때 서울특별시 노원구와 대구광역시 수성구가 인기가 많은데
# 코로나로 인해
